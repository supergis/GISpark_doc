# %%
# !make clean
# Out:
# rm -rf build/*

# %%
# !make html
# Out:
# sphinx-build -b html -d build/doctrees   source build/html
# Running Sphinx v1.4.1
# making output directory...
# loading translations [zh_CN]... done
# loading pickled environment... not yet created
# building [mo]: targets for 0 po files that are out of date
# building [html]: targets for 48 source files that are out of date
# updating environment: 48 added, 0 changed, 0 removed
# /home/supermap/GISpark/GISpark_doc/source/geospatial/geojson/geojson.ipynb: WARNING: file not found: 'geospatial/geojson/urn:ogc:def:crs:OGC:1.3:CRS84'
# /home/supermap/GISpark/GISpark_doc/source/geospatial/openstreetmap/osm-overpass-node.ipynb: WARNING: file not found: 'geospatial/openstreetmap/http:www.openstreetmap.org'
# /home/supermap/GISpark/GISpark_doc/source/jupyter/jupyter_quickstart.ipynb: WARNING: file not found: 'jupyter/How%20to%20Install%20PySpark%20and%20Integrate%20with%20IPython%20Notebook'
#
# ...

# %%
#!make latexpdf
